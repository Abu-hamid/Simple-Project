# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1) , index = pd.date_range('2023-07-17' , periods = 1000) , columns = ['data'])
df
# Out:
#                 data
# 2023-07-17  0.588131
# 2023-07-18  0.897714
# 2023-07-19  0.891531
# 2023-07-20  0.815837
# 2023-07-21  0.035890
# ...              ...
# 2026-04-07  0.992189
# 2026-04-08  0.756037
# 2026-04-09  0.299186
# 2026-04-10  0.261712
# 2026-04-11  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.data.cumsum().plot()
# Out:
# <Axes: >

# %%
df['data1'] = df.data.cumsum()

# %%
df['data2'] = df['data'].apply(lambda x : x*3)

# %%
df
# Out:
#                 data       data1     data2
# 2023-07-17  0.588131    0.588131  1.764392
# 2023-07-18  0.897714    1.485845  2.693141
# 2023-07-19  0.891531    2.377375  2.674592
# 2023-07-20  0.815837    3.193213  2.447512
# 2023-07-21  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2026-04-07  0.992189  495.812936  2.976566
# 2026-04-08  0.756037  496.568973  2.268112
# 2026-04-09  0.299186  496.868159  0.897559
# 2026-04-10  0.261712  497.129872  0.785137
# 2026-04-11  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize=(5,5))
# Out:
# <Axes: >

# %%
df1 = sns.load_dataset('iris')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
gf = df1.plot(figsize= (10 ,5) ,title = "iris data")
gf.set_xlabel('This is the x axis')
gf.set_ylabel('This is the y axis')
# Out:
# Text(0, 0.5, 'This is the y axis')

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.iloc[0][0:4].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df2 = sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df3 = pd.DataFrame(np.random.rand(10,4) , columns = ['a' , 'b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df3.plot.bar()## barh() in case of horizontal
# Out:
# <Axes: >

# %%
df1.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['sepal_length'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind = 'hist' , stacked = True , bins  =100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.hist(figsize = (10,10) , color = 'green' , alpha = .8)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.plot.scatter(x = 'sepal_length' , y = 'sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.scatter(x = 'sepal_length' , y = 'sepal_width' , c = 'petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.scatter(x = 'sepal_length' , y = 'sepal_width' , label = 'Deptt' ,s= 180  , c = 'petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x = 'sepal_length' , y = 'sepal_width' , label = 'Deptt' ,gridsize =10)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
d = df.iloc[0]

# %%
d.plot.pie()
# Out:
# <Axes: ylabel='2023-07-17 00:00:00'>

# %%
iris = df1.head(3).T

# %%
iris.iloc[0:4].plot.pie(subplots=True , figsize = (25,25) , fontsize = 20, autopct = '%.2f' )
# Out:
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
 df['data'].plot(style = 'r+' ,legend = True , label = "Deptt")
# Out:
# <Axes: >

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
py.offline.init_notebook_mode(connected = True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df1.iplot()

# %%
df2.iplot(x  ='fare' , y = 'age' , kind = 'scatter' , mode = 'marker' , xTitle = 'fare'  ,yTitle = 'age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df2.iplot(x  ='fare' , y = 'age' , kind = 'scatter' , mode = 'marker' , xTitle = 'fare'  ,yTitle = 'age')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}

# %%
cf.set_config_file(theme = 'solar')
df2.iplot(x  ='fare' , y = 'age' , kind = 'scatter' , mode = 'marker' , xTitle = 'fare'  ,yTitle = 'age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 2
#       1 cf.set_config_file(theme = 'solar')
# ----> 2 df2.iplot(x  ='fare' , y = 'age' , kind = 'scatter' , mode = 'marker' , xTitle = 'fare'  ,yTitle = 'age')
#
# ...
